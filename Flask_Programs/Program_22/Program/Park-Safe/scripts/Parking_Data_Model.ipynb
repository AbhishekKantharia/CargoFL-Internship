# %%
import pandas as pd
import numpy as np
from datetime import date, datetime, timedelta
import calendar
import matplotlib.pyplot as plt
import datetime as dt

# %%
from sklearn.naive_bayes import GaussianNB

# %%
data_df = pd.read_csv('Police_Department_Incident_Reports__2018_to_Present.csv')
filtered_data_df = data_df.filter(['Incident Datetime', 'Incident Day of Week','Incident Description', 'Analysis Neighborhood', 'Intersection', 'Latitude', 'Longitude'], axis=1)
incident_df = filtered_data_df.loc[[desc.startswith('Vehicle, Stolen') for desc in filtered_data_df['Incident Description']], :]
#incident_df = pd.read_csv('Filtered_Incident_Report.csv')

# %%
incident_df.shape
# Out:
# (15119, 7)

# %%
filtered_data_df = incident_df.filter(['Incident Datetime', 'Incident Day of Week', 'Analysis Neighborhood', 'Intersection', 'Latitude', 'Longitude'], axis=1)

# %%
# filter incident for year 2019
filtered_data_df['Incident Datetime'] = pd.to_datetime(filtered_data_df['Incident Datetime'])
filtered_data_df= filtered_data_df[filtered_data_df['Incident Datetime'].dt.year==2019]
filtered_data_df = filtered_data_df.dropna()

# %%
filtered_data_df.head()
# Out:
#         Incident Datetime Incident Day of Week Analysis Neighborhood  \
# 2252  2019-08-09 00:00:00               Friday       South of Market
# 7976  2019-07-13 23:16:00             Saturday        Bernal Heights
# 18148 2019-08-11 17:00:00               Sunday               Portola
# 18878 2019-07-18 12:00:00             Thursday           Mission Bay
# 20420 2019-10-19 15:00:00             Saturday     Lone Mountain/USF
#
#                      Intersection   Latitude   Longitude
# 2252           WELSH ST \ 05TH ST  37.777372 -122.399763
# 7976    MISSION ST \ RICHLAND AVE  37.736061 -122.424466
# 18148     BOWDOIN ST \ SILVER AVE  37.730249 -122.412338
# 18878    04TH ST \ LONG BRIDGE ST  37.773467 -122.391434
# 20420  MCALLISTER ST \ PARSONS ST  37.775611 -122.455441

# %%
# Get parking data
parking_data = pd.read_csv('Parking_Meters.csv')
# Out:
# D:\Software\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (28,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
parking_data.shape
# Out:
# (33288, 45)

# %%
#parking_data = parking_data[['PARKING_SPACE_ID', 'STREET_NAME','LONGITUDE', 'LATITUDE' ]]

# %%
parking_data.head()
# Out:
#    OBJECTID  PARKING_SPACE_ID    POST_ID MS_PAY_STATION_ID  MS_SPACE_NUM  \
# 0     33521            132627  818-01520                 -             0
# 1     33670            131615  831-04060                 -             0
# 2     33707            131649  561-02041         561-02040             1
# 3     33848            132817  561-03160                 -             0
# 4     33895            132860  658-01430                 -             0
#
#   SENSOR_FLAG ON_OFFSTREET_TYPE  OSP_ID JURISDICTION  PM_DISTRICT_ID  ...  \
# 0           Y                ON       0         PORT               2  ...
# 1           Y                ON       0         PORT               2  ...
# 2           N                ON       0        SFMTA               1  ...
# 3           N                ON       0        SFMTA               2  ...
# 4           E                ON       0        SFMTA               1  ...
#
#    NFC_KEY SPT_CODE     COLLECTION_ROUTE_DESC COLLECTION_SUBROUTE_DESC  \
# 0      NaN      NaN                       NaN                      NaN
# 1      NaN      NaN                       NaN                      NaN
# 2      NaN      NaN                       NaN                      NaN
# 3     3SP5      NaN                       NaN                      NaN
# 4     4RJ4      NaN  Folsom St: Unit-800 1st:           Spear Unit-300
#
#                            shape Neighborhoods SF Find Neighborhoods  \
# 0  POINT (-122.389114 37.784286)            31                    31
# 1  POINT (-122.388504 37.789272)            30                    30
# 2   POINT (-122.39328 37.790424)           108                   108
# 3   POINT (-122.39142 37.788933)            30                    30
# 4   POINT (-122.39334 37.792076)           108                   108
#
#   Current Police Districts Current Supervisor Districts Analysis Neighborhoods
# 0                        1                           10                      8
# 1                        1                           10                      8
# 2                        1                           10                      8
# 3                        1                           10                      8
# 4                        1                           10                      8
#
# [5 rows x 45 columns]

# %%
pip install shapely
# Out:
# Requirement already satisfied: shapely in d:\software\lib\site-packages (1.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import math
from shapely.geometry import Polygon, Point
import pandas as pd
import json

# %%
with open('sf_neighborhoods.geojson', 'r') as f:
    geo_data = json.load(f)

# %%

nbr_to_poly = dict()
for nbr in geo_data['features']:
    nbr_to_poly[nbr['properties']['name']] = Polygon(nbr['geometry']['coordinates'][0][0])
# %%
nbr_adjusted = list()
for lon, lat in zip(filtered_data_df['Longitude'], filtered_data_df['Latitude']):
    correct_nbr = None
    if not math.isnan(lon):
        p = Point(lon, lat)
        for nbr, polygon in nbr_to_poly.items():
            if polygon.contains(p):
                correct_nbr = nbr
                break
    nbr_adjusted.append(correct_nbr)
# %%
filtered_data_df.drop('Analysis Neighborhood', axis=1, inplace=True)
filtered_data_df['Analysis Neighborhood'] = nbr_adjusted

# %%
filtered_data_df['Incident hour'] = filtered_data_df['Incident Datetime'].apply(lambda x: x.hour)

# %%
filtered_data_df['Incident month'] = filtered_data_df['Incident Datetime'].apply(lambda x: x.month)

# %%
filtered_data_df['Incident Date'] = filtered_data_df['Incident Datetime'].dt.date

# %%
# filtered_data_df=filtered_data_df.drop('Incident Datetime', axis =1)

# %%
parking_data.rename(columns={"LATITUDE":"Latitude", "LONGITUDE":"Longitude"},inplace=True)

# %%
# %%
with open('sf_neighborhoods.geojson', 'r') as f:
    geo_data = json.load(f)

# %%

nbr_to_poly = dict()
for nbr in geo_data['features']:
    nbr_to_poly[nbr['properties']['name']] = Polygon(nbr['geometry']['coordinates'][0][0])
# %%
nbr_adjusted = list()
for lon, lat in zip(parking_data['Longitude'], parking_data['Latitude']):
    correct_nbr = None
    if not math.isnan(lon):
        p = Point(lon, lat)
        for nbr, polygon in nbr_to_poly.items():
            if polygon.contains(p):
                correct_nbr = nbr
                break
    nbr_adjusted.append(correct_nbr)
# %%
parking_data['Analysis Neighborhood'] = nbr_adjusted

# %%
parking_data.head()
# Out:
#    OBJECTID  PARKING_SPACE_ID    POST_ID MS_PAY_STATION_ID  MS_SPACE_NUM  \
# 0     33521            132627  818-01520                 -             0
# 1     33670            131615  831-04060                 -             0
# 2     33707            131649  561-02041         561-02040             1
# 3     33848            132817  561-03160                 -             0
# 4     33895            132860  658-01430                 -             0
#
#   SENSOR_FLAG ON_OFFSTREET_TYPE  OSP_ID JURISDICTION  PM_DISTRICT_ID  ...  \
# 0           Y                ON       0         PORT               2  ...
# 1           Y                ON       0         PORT               2  ...
# 2           N                ON       0        SFMTA               1  ...
# 3           N                ON       0        SFMTA               2  ...
# 4           E                ON       0        SFMTA               1  ...
#
#    SPT_CODE     COLLECTION_ROUTE_DESC COLLECTION_SUBROUTE_DESC  \
# 0       NaN                       NaN                      NaN
# 1       NaN                       NaN                      NaN
# 2       NaN                       NaN                      NaN
# 3       NaN                       NaN                      NaN
# 4       NaN  Folsom St: Unit-800 1st:           Spear Unit-300
#
#                            shape Neighborhoods SF Find Neighborhoods  \
# 0  POINT (-122.389114 37.784286)            31                    31
# 1  POINT (-122.388504 37.789272)            30                    30
# 2   POINT (-122.39328 37.790424)           108                   108
# 3   POINT (-122.39142 37.788933)            30                    30
# 4   POINT (-122.39334 37.792076)           108                   108
#
#   Current Police Districts Current Supervisor Districts  \
# 0                        1                           10
# 1                        1                           10
# 2                        1                           10
# 3                        1                           10
# 4                        1                           10
#
#   Analysis Neighborhoods Analysis Neighborhood
# 0                      8           South Beach
# 1                      8           Rincon Hill
# 2                      8    Financial District
# 3                      8           Rincon Hill
# 4                      8    Financial District
#
# [5 rows x 46 columns]

# %%
filtered_data_df.head()
# Out:
#         Incident Datetime Incident Day of Week                Intersection  \
# 2252  2019-08-09 00:00:00               Friday          WELSH ST \ 05TH ST
# 7976  2019-07-13 23:16:00             Saturday   MISSION ST \ RICHLAND AVE
# 18148 2019-08-11 17:00:00               Sunday     BOWDOIN ST \ SILVER AVE
# 18878 2019-07-18 12:00:00             Thursday    04TH ST \ LONG BRIDGE ST
# 20420 2019-10-19 15:00:00             Saturday  MCALLISTER ST \ PARSONS ST
#
#         Latitude   Longitude Analysis Neighborhood  Incident hour  \
# 2252   37.777372 -122.399763       South of Market              0
# 7976   37.736061 -122.424466            Holly Park             23
# 18148  37.730249 -122.412338               Portola             17
# 18878  37.773467 -122.391434           Mission Bay             12
# 20420  37.775611 -122.455441         Lone Mountain             15
#
#        Incident month Incident Date
# 2252                8    2019-08-09
# 7976                7    2019-07-13
# 18148               8    2019-08-11
# 18878               7    2019-07-18
# 20420              10    2019-10-19

# %%
# randonly select 1000 parking spots
parking_data.sample(frac = 1) 
parking_data_small = parking_data[:1000]

# %%
parking_data_small.shape
# Out:
# (1000, 46)

# %%
parking_data_small.to_csv('Parking_Spots_Data.csv')

# %%
incident_parking = (filtered_data_df.assign(dummy=1)
    .merge(parking_data_small.assign(dummy=1),on='dummy')
    .query('abs(Latitude_x-Latitude_y)<=0.001 and abs(Longitude_x-Longitude_y)<=0.001')
    .drop('dummy', axis=1)
)

# %%
incident_parking[['Latitude_x','Latitude_y', 'Longitude_x', 'Longitude_y']]
# Out:
#          Latitude_x  Latitude_y  Longitude_x  Longitude_y
# 253       37.777372   37.777607  -122.399763  -122.399905
# 604       37.777372   37.778030  -122.399763  -122.399848
# 759       37.777372   37.778273  -122.399763  -122.399538
# 785       37.777372   37.776646  -122.399763  -122.399005
# 3354      37.773467   37.773964  -122.391434  -122.392050
# ...             ...         ...          ...          ...
# 4890077   37.784501   37.784076  -122.419455  -122.419544
# 4890693   37.784501   37.784415  -122.419455  -122.419917
# 4890815   37.784501   37.783746  -122.419455  -122.419391
# 4890972   37.784501   37.784396  -122.419455  -122.420065
# 4891536   37.778069   37.778756  -122.405069  -122.405777
#
# [4925 rows x 4 columns]

# %%
pip install geopy
# Out:
# Collecting geopyNote: you may need to restart the kernel to use updated packages.
#   Downloading geopy-2.0.0-py3-none-any.whl (111 kB)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.50-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.0.0

# %%
from geopy.distance import geodesic

# %%
for index, row in incident_parking.iterrows():
    dist = geodesic((row['Latitude_x'], row['Longitude_x']), (row['Latitude_y'], row['Longitude_x'])).km
    if(dist >=0.1):
      incident_parking.drop(index, inplace =True)

# %%
incident_parking.shape
# Out:
# (4333, 14)

# %%
# hour_range_map = {
#   0: "0-3",
#   1: "4-7",
#   2: "8-11",
#   3: "12-15",
#   4: "16-19",
#   5: "20-23", 
# }

# %%
# incident_parking['hour_range'] = incident_parking['Incident hour'].apply(lambda x:hour_range_map[(int)(x/4)])

# %%
incident_parking.drop(['Latitude_x','Longitude_x'],axis=1, inplace=True)
# incident_parking.drop('Analysis Neighborhood_x', axis =1, inplace = True)

# %%
incident_parking.rename(columns={"Latitude_y":"Latitude", "Longitude_y":"Longitude", "Analysis Neighborhood_y":"Analysis Neighborhood" },inplace=True)

# %%
positive_df = incident_parking.filter(['Incident Date','PARKING_SPACE_ID','Incident Day of Week', 'Incident hour' , 'Incident month','Analysis Neighborhood','Longitude','Latitude'], axis=1)

# %%
positive_df=positive_df.dropna()
positive_df['Incident occured'] =1
positive_df.head()
# Out:
#      Incident Date  PARKING_SPACE_ID Incident Day of Week  Incident hour  \
# 253     2019-08-09            138213               Friday              0
# 604     2019-08-09            137229               Friday              0
# 785     2019-08-09            138243               Friday              0
# 3354    2019-07-18            138502             Thursday             12
# 3428    2019-07-18            138634             Thursday             12
#
#       Incident month Analysis Neighborhood   Longitude   Latitude  \
# 253                8       South of Market -122.399905  37.777607
# 604                8       South of Market -122.399848  37.778030
# 785                8       South of Market -122.399005  37.776646
# 3354               7           Mission Bay -122.392050  37.773964
# 3428               7           Mission Bay -122.392283  37.772939
#
#       Incident occured
# 253                  1
# 604                  1
# 785                  1
# 3354                 1
# 3428                 1

# %%
positive_df.shape
# Out:
# (4333, 9)

# %%
from datetime import date, datetime, timedelta

def datespan(startDate, endDate, delta=timedelta(days=1)):
    currentDate = startDate
    while currentDate < endDate:
        yield currentDate
        currentDate += delta

# %%
hour_range = []
date =[]
day=[]

for timestamp in datespan(datetime(2019, 1, 1, 0, 0), 
                          datetime(2019, 12, 31, 23, 0), 
                          delta=timedelta(hours=4)):
    x= hour_range_map[(int)((timestamp.hour)/4)]
    hour_range.append(x)
    date.append(timestamp.date())
    day.append(calendar.day_name[timestamp.date().weekday()])
#     print (x , timestamp.date(),calendar.day_name[timestamp.date().weekday()])
    
negative_df = pd.DataFrame({'Incident Date': date,'Incident Day of Week':day,'hour_range':hour_range})

# %%
negative_df['Incident occured'] =0
negative_df.tail(20)
# Out:
#      Incident Date Incident Day of Week hour_range  Incident occured
# 2170    2019-12-28             Saturday      16-19                 0
# 2171    2019-12-28             Saturday      20-23                 0
# 2172    2019-12-29               Sunday        0-3                 0
# 2173    2019-12-29               Sunday        4-7                 0
# 2174    2019-12-29               Sunday       8-11                 0
# 2175    2019-12-29               Sunday      12-15                 0
# 2176    2019-12-29               Sunday      16-19                 0
# 2177    2019-12-29               Sunday      20-23                 0
# 2178    2019-12-30               Monday        0-3                 0
# 2179    2019-12-30               Monday        4-7                 0
# 2180    2019-12-30               Monday       8-11                 0
# 2181    2019-12-30               Monday      12-15                 0
# 2182    2019-12-30               Monday      16-19                 0
# 2183    2019-12-30               Monday      20-23                 0
# 2184    2019-12-31              Tuesday        0-3                 0
# 2185    2019-12-31              Tuesday        4-7                 0
# 2186    2019-12-31              Tuesday       8-11                 0
# 2187    2019-12-31              Tuesday      12-15                 0
# 2188    2019-12-31              Tuesday      16-19                 0
# 2189    2019-12-31              Tuesday      20-23                 0

# %%
negative_df.shape
# Out:
# (2190, 5)

# %%
negative_df= negative_df.sample(frac=1)

# %%
negative_df['Incident hour'] = negative_df['hour_range'].apply(lambda x: np.random.randint(0,4) if x == '0-3' else (np.random.randint(4,8) if x == '4-7' else (np.random.randint(8,12) if x == '8-11' else (np.random.randint(12,16) if x == '12-15' else (np.random.randint(16,20) if x == '16-19' else np.random.randint(20,24))))))

# %%
negative_df =negative_df.drop('hour_range', axis =1)
negative_df.head(20)
# Out:
#      Incident Date Incident Day of Week  Incident occured  Incident hour
# 941     2019-06-06             Thursday                 0             21
# 2129    2019-12-21             Saturday                 0             20
# 824     2019-05-18             Saturday                 0             11
# 429     2019-03-13            Wednesday                 0             12
# 1706    2019-10-12             Saturday                 0             10
# 369     2019-03-03               Sunday                 0             15
# 2180    2019-12-30               Monday                 0             11
# 178     2019-01-30            Wednesday                 0             16
# 591     2019-04-09              Tuesday                 0             15
# 1173    2019-07-15               Monday                 0             13
# 1092    2019-07-02              Tuesday                 0              0
# 118     2019-01-20               Sunday                 0             16
# 1099    2019-07-03            Wednesday                 0              4
# 1269    2019-07-31            Wednesday                 0             12
# 1732    2019-10-16            Wednesday                 0             17
# 1938    2019-11-20            Wednesday                 0              2
# 1158    2019-07-13             Saturday                 0              3
# 1380    2019-08-19               Monday                 0              2
# 504     2019-03-26              Tuesday                 0              3
# 231     2019-02-08               Friday                 0             15

# %%
negative_df.shape
# Out:
# (2190, 4)

# %%
# neighborhood_list = positive_df['Analysis Neighborhood'].unique().tolist()
parking_id_list = parking_data_small['PARKING_SPACE_ID'].unique().tolist()
len(parking_id_list)
# Out:
# 1000

# %%
(x,y,z)=parking_data_small[parking_data_small['PARKING_SPACE_ID'] == 132627][['Longitude','Latitude','Analysis Neighborhood']].values[0]

# %%
negative_data = pd.DataFrame()
for p_id in parking_id_list:
    negative_df['PARKING_SPACE_ID'] = p_id
    (x,y,z) = parking_data_small[parking_data_small['PARKING_SPACE_ID'] == p_id][['Longitude','Latitude','Analysis Neighborhood']].values[0]
    negative_df['Longitude'] = x
    negative_df['Latitude'] = y
    negative_df['Analysis Neighborhood'] = z    
    negative_data = pd.concat([negative_data,negative_df])

# %%
for index, row in parking_data_small.iterrows():
    print(row['c1'], row['c2'])

# %%
negative_data.rename(columns = {'hour_range':'Incident hour'}, inplace = True)

# %%
on = ['Incident Date', 'Incident Day of Week', 'Incident hour','PARKING_SPACE_ID']

negative_data = (negative_data.merge(positive_df[on], on=on, how='left', indicator=True)
              .query('_merge == "left_only"').drop('_merge', 1))

# %%
positive_df.shape
# Out:
# (4333, 9)

# %%
negative_data.shape
# Out:
# (2189017, 8)

# %%
data = pd.concat([positive_df,negative_data])

# %%
data['Incident month'] = data['Incident Date'].apply(lambda x: x.month)

# %%
data.drop(['Incident Date'],inplace=True, axis=1)
data
# Out:
#          PARKING_SPACE_ID Incident Day of Week  Incident hour  Incident month  \
# 253                138213               Friday              0               8
# 604                137229               Friday              0               8
# 785                138243               Friday              0               8
# 3354               138502             Thursday             12               7
# 3428               138634             Thursday             12               7
# ...                   ...                  ...            ...             ...
# 2190017            135233             Saturday              7               1
# 2190018            135233               Friday             14               1
# 2190019            135233             Saturday             12               8
# 2190020            135233               Friday             22               5
# 2190021            135233               Monday             20              11
#
#         Analysis Neighborhood   Longitude   Latitude  Incident occured
# 253           South of Market -122.399905  37.777607                 1
# 604           South of Market -122.399848  37.778030                 1
# 785           South of Market -122.399005  37.776646                 1
# 3354              Mission Bay -122.392050  37.773964                 1
# 3428              Mission Bay -122.392283  37.772939                 1
# ...                       ...         ...        ...               ...
# 2190017   Northern Waterfront -122.399924  37.799315                 0
# 2190018   Northern Waterfront -122.399924  37.799315                 0
# 2190019   Northern Waterfront -122.399924  37.799315                 0
# 2190020   Northern Waterfront -122.399924  37.799315                 0
# 2190021   Northern Waterfront -122.399924  37.799315                 0
#
# [2193350 rows x 8 columns]

# %%
data.to_csv('Dataset1_Parking_Data.csv')

# %%
data = pd.concat([data,pd.get_dummies(data[['Incident Day of Week','Analysis Neighborhood']])],axis=1)

# %%
data.drop(['Incident Day of Week','Analysis Neighborhood'],axis=1,inplace=True)

# %%
label = data.pop('Incident occured')

# %%
data['Incident occured'] = label

# %%
data['Incident occured'] = data['Incident occured'].apply(lambda x: 1 if x=="Yes" else 0)

# %%
len(data[data['Incident occured']==1])/len(data)
# Out:
# 0.0019756150828841882

# %%
data['Incident occured']
# Out:
# 253        1
# 604        1
# 785        1
# 3354       1
# 3428       1
#           ..
# 2190044    0
# 2190045    0
# 2190046    0
# 2190047    0
# 2190048    0
# Name: Incident occured, Length: 2193241, dtype: int64

# %%
data.iloc[:,-1]
# Out:
# 156617     0
# 85691      0
# 408186     0
# 1662547    0
# 106164     0
#           ..
# 529247     0
# 895150     0
# 1302627    0
# 563742     0
# 1298664    0
# Name: Incident occured, Length: 2190182, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
# import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
data = pd.read_csv('../filtered_data/Dataset1_Parking_Data/Dataset1_Parking_Data.csv')
weekdays = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
data = data.drop(['Unnamed: 0', 'Analysis Neighborhood'], axis=1).replace({'Incident Day of Week': {day: weekdays.index(day) for day in weekdays}})
data.head()
# Out:
#    PARKING_SPACE_ID  Incident Day of Week  Incident hour  Incident month  \
# 0            138213                     5              0               8
# 1            137229                     5              0               8
# 2            138243                     5              0               8
# 3            138502                     4             12               7
# 4            138634                     4             12               7
#
#     Longitude   Latitude  Incident occured
# 0 -122.399905  37.777607                 1
# 1 -122.399848  37.778030                 1
# 2 -122.399005  37.776646                 1
# 3 -122.392050  37.773964                 1
# 4 -122.392283  37.772939                 1

# %%
data = pd.read_csv('subdataset2.csv')
data.head()
# Out:
#    Unnamed: 0  hour  dow  month   latitude   longitude      loc_prob  label
# 0           0     0    4      8  37.777372 -122.399763  2.297776e-08      1
# 1           1    23    5      7  37.736061 -122.424466  1.237617e-06      1
# 2           2    17    6      8  37.730249 -122.412338  1.219130e-11      1
# 3           3     1    1      1  37.786101 -122.418088  2.109190e-06      1
# 4           4     8    1      1  37.719109 -122.483104  4.581974e-07      1

# %%
data = data.drop(['PARKING_SPACE_ID'], axis=1)

# %%
data= data.sample(frac=1)
X = data.iloc[:,1:-1]
y = data.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=0)

# %%
X
# Out:
#       hour  dow  month   latitude   longitude      loc_prob
# 2949    17    3      2  37.731339 -122.439660  5.109646e-07
# 4934     2    3      3  37.769077 -122.401787  9.211198e-12
# 3046    21    4     10  37.797249 -122.435692  1.386499e-07
# 2432    12    1      7  37.801240 -122.422304  2.410399e-08
# 3228    23    6      9  37.772915 -122.416151  2.425746e-06
# ...    ...  ...    ...        ...         ...           ...
# 998     10    1      3  37.752373 -122.416266  2.164019e-07
# 4030     0    6      7  37.721995 -122.482360  7.419039e-08
# 5610     0    3      2  37.807533 -122.406014  1.359101e-10
# 4777    14    4      3  37.752784 -122.477175  4.465671e-94
# 1006    10    3      3  37.757035 -122.418901  1.165639e-06
#
# [7350 rows x 6 columns]

# %%
model = LogisticRegression(solver='lbfgs')
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr_prob = model.predict_proba(X_test)

# %%
ns_probs = [0 for _ in range(len(y_test))]

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
nb_prob =nb.predict_proba(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
clf = DecisionTreeClassifier(max_depth = 5)
# clf = RandomForestClassifier(n_estimators =2)
clf.fit(X_train,y_train)
rf_prob=clf.predict_proba(X_test)

# %%
temp = X_train[['month', 'latitude', 'longitude']]

# %%
rf_prob = rfe.estimator_.predict_proba(temp)

# %%
lr_probs = lr_prob[:, 1]
nb_probs = nb_prob[:, 1]
rf_probs = rf_prob[:, 1]
# calculate scores
ns_auc = roc_auc_score(y_test, ns_probs)
lr_auc = roc_auc_score(y_test, lr_probs)
nb_auc = roc_auc_score(y_test, nb_probs)
rf_auc = roc_auc_score(y_test, rf_probs)
# summarize scores
print('Default: ROC AUC=%.3f' % (ns_auc))
print('Logistic: ROC AUC=%.3f' % (lr_auc))
print('Naive Bayes: ROC AUC=%.3f' % (nb_auc))
print('Decision Tree: ROC AUC=%.3f' % (rf_auc))
# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
nb_fpr, nb_tpr, _ = roc_curve(y_test, nb_probs)
rf_fpr, rf_tpr, _ = roc_curve(y_test, rf_probs)
# plot the roc curve for the model
fig = plt.figure(figsize=(6,6), dpi=100)
plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Default')
plt.plot(lr_fpr, lr_tpr, label='Logistic')
plt.plot(nb_fpr, nb_tpr, label='Naive Bayes')
plt.plot(rf_fpr, rf_tpr, label='Decision Tree')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plot
plt.show()
# Out:
# Default: ROC AUC=0.500
# Logistic: ROC AUC=0.847
# Naive Bayes: ROC AUC=0.886
# Decision Tree: ROC AUC=1.000

# %%
rfe.estimator_
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.feature_selection import RFECV

rfe = RFECV(DecisionTreeClassifier()).fit(X, y)

# %%
X
# Out:
#       hour  dow  month   latitude   longitude      loc_prob
# 2949    17    3      2  37.731339 -122.439660  5.109646e-07
# 4934     2    3      3  37.769077 -122.401787  9.211198e-12
# 3046    21    4     10  37.797249 -122.435692  1.386499e-07
# 2432    12    1      7  37.801240 -122.422304  2.410399e-08
# 3228    23    6      9  37.772915 -122.416151  2.425746e-06
# ...    ...  ...    ...        ...         ...           ...
# 998     10    1      3  37.752373 -122.416266  2.164019e-07
# 4030     0    6      7  37.721995 -122.482360  7.419039e-08
# 5610     0    3      2  37.807533 -122.406014  1.359101e-10
# 4777    14    4      3  37.752784 -122.477175  4.465671e-94
# 1006    10    3      3  37.757035 -122.418901  1.165639e-06
#
# [7350 rows x 6 columns]

# %%
rfe.ranking_
# Out:
# array([2, 4, 1, 1, 1, 3])

# %%
rfe.support_
# Out:
# array([ True, False,  True,  True])

# %%
former = np.load('loc_prob1.npy')
middle = np.load('loc_prob2.npy')
latter = np.load('loc_prob.npy')

# %%
former.shape, middle.shape, latter.shape
# Out:
# ((1450,), (2750,), (3150,))

# %%
dataset2_df = pd.read_csv('../filtered_data/Dataset2_2019.csv')
dataset2_df.shape
# Out:
# (34265, 7)

# %%
dataset2_df.head()
# Out:
#    Unnamed: 0  hour  dow  month   latitude   longitude  label
# 0           0     0    4      8  37.777372 -122.399763      1
# 1           1    23    5      7  37.736061 -122.424466      1
# 2           2    17    6      8  37.730249 -122.412338      1
# 3           3     1    1      1  37.786101 -122.418088      1
# 4           4     8    1      1  37.719109 -122.483104      1

# %%
idx = list(range(len(former))) + list(range(n//3, n//3 + len(middle))) + list(range((2*n)//3, (2*n)//3 + len(latter)))
len(idx), len(former)+len(middle)+len(latter)
# Out:
# (7350, 7350)

# %%
n = dataset2_df.shape[0]
sub2_df = dataset2_df.iloc[idx, :]

# %%
# sub2_df['loc_prob'] = list(former)+list(middle)+list(latter)
# sub2_df.drop(['Unnamed: 0'], axis=1, inplace=True)
sub2_df.head()
# Out:
#    hour  dow  month   latitude   longitude  label      loc_prob
# 0     0    4      8  37.777372 -122.399763      1  2.297776e-08
# 1    23    5      7  37.736061 -122.424466      1  1.237617e-06
# 2    17    6      8  37.730249 -122.412338      1  1.219130e-11
# 3     1    1      1  37.786101 -122.418088      1  2.109190e-06
# 4     8    1      1  37.719109 -122.483104      1  4.581974e-07

# %%
# sub2_df = sub2_df[list(sub2_df.columns.values[:-2])+['loc_prob', 'label']]
# sub2_df.reset_index(drop=True, inplace=True)
sub2_df.to_csv('subdataset2.csv')

# %%
ps_prob = list(np.load('park_spot_prob.npy'))
len(ps_prob)
# Out:
# 1000

# %%
data.head()
# Out:
#    PARKING_SPACE_ID  Incident Day of Week  Incident hour  Incident month  \
# 0            138213                     5              0               8
# 1            137229                     5              0               8
# 2            138243                     5              0               8
# 3            138502                     4             12               7
# 4            138634                     4             12               7
#
#     Longitude   Latitude  Incident occured
# 0 -122.399905  37.777607                 1
# 1 -122.399848  37.778030                 1
# 2 -122.399005  37.776646                 1
# 3 -122.392050  37.773964                 1
# 4 -122.392283  37.772939                 1

# %%
park_meters_df = pd.read_csv('../filtered_data/Parking_Spots_Data.csv')
ps_id = park_meters_df['PARKING_SPACE_ID']
len(ps_id)
# Out:
# 1000

# %%
temp = pd.DataFrame({'PARKING_SPACE_ID': ps_id, 'loc_prob':ps_prob})
data = data.merge(temp).drop(['PARKING_SPACE_ID'], axis=1)

# %%
sub2_df.columns
# Out:
# Index(['hour', 'dow', 'month', 'latitude', 'longitude', 'loc_prob', 'label'], dtype='object')

# %%
# data.columns = ['dow', 'hour', 'month', 'longitude', 'latitude', 'label', 'loc_prob']
data[sub2_df.columns]['label'].value_counts()
# Out:
# 0    2189017
# 1       4333
# Name: label, dtype: int64

# %%
rfe.estimator_
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import seaborn as sn
import matplotlib.pyplot as plt

# %%
data= data.sample(frac=1)
X = data.iloc[:,:-1]
y = data.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=0)

# %%
y_train
# Out:
# 1459260    No
# 1707305    No
# 359232     No
# 907950     No
# 2876630    No
#            ..
# 2783504    No
# 626932     No
# 2888259    No
# 1781607    No
# 84688      No
# Name: Incident occured, Length: 2167183, dtype: category
# Categories (2, object): ['No', 'Yes']

# %%
logistic_regression= LogisticRegression()
logistic_regression.fit(X_train,y_train)
y_pred=logistic_regression.predict(X_test)

# %%
log_confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sn.heatmap(log_confusion_matrix, annot=True)
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>

# %%
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred))
plt.show()
# Out:
# Accuracy:  0.9825343402304494

# %%
recall_log = log_confusion_matrix.iloc[1][1]/ (confusion_matrix.iloc[1][1]+ confusion_matrix.iloc[1][0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-250-9d5abcf59cd8> in <module>
# ----> 1 recall_log = log_confusion_matrix.iloc[1][1]/ (confusion_matrix.iloc[1][1]+ confusion_matrix.iloc[1][0])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     877
#     878         if is_integer(key) and self.index._should_fallback_to_positional():
# --> 879             return self._values[key]
#     880
#     881         elif key_is_scalar:
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
recall_log*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-251-8002da98bf59> in <module>
# ----> 1 recall_log*100
#
# NameError: name 'recall_log' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sn.heatmap(confusion_matrix, annot=True)
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>

# %%
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred))
plt.show()
# Out:
# Accuracy:  0.8886040760329982

# %%
data['Incident occured'] = data['Incident occured'].apply(lambda x: 'Yes' if x==1 else 'No')

# %%
fig = plt.figure(figsize=(4,4), dpi=100)

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
plt.hist(data['Incident occured'], )
plt.xlabel('Incident Occured')
plt.ylabel('Count (in millions)')
plt.show()

# %%
data['Incident occured'] = data['Incident occured'].apply(lambda x: 'Yes' if x == 1 else 'No')

# %%
confusion_matrix
# Out:
# Predicted       0     1
# Actual
# 0          191037  3116
# 1           21412  6023

# %%
np.sum(y_test ==1)
# Out:
# 27435

# %%
recall = confusion_matrix.iloc[1][1]/ (confusion_matrix.iloc[1][1]+ confusion_matrix.iloc[1][0])

# %%
recall*100
# Out:
# 21.953708766174596

# %% [markdown]
# ## Naive Bayes

# %%
X_train
# Out:
#         Incident Day of Week_Friday  Incident Day of Week_Monday  \
# 600099                                  0
# 53691                                   0
# 370299                                  0
#
#         Analysis Neighborhood_Western Addition  \
# 346129                                       0
# 474741                                       0
# 475949                                       0
# 427945                                       0
# 436512                                       0
# ...                                        ...
# 323649                                       0
# 615473                                       0
# 600099                                       0
# 53691                                        0
# 370299                                       0
#
#         Analysis Neighborhood_Westwood Highlands  \
# 346129                                         0
# 474741                                         0
# 475949                                         0
# 427945                                         0
# 436512                                         0
# ...                                          ...
# 323649                                         0
# 615473                                         0
# 600099                                         0
# 53691                                          0
# 370299                                         0
#
#         Analysis Neighborhood_Westwood Park
# 346129                                    0
# 474741                                    0
# 475949                                    0
# 427945                                    0
# 436512                                    0
# ...                                     ...
# 323649                                    0
# 615473                                    0
# 600099                                    0
# 53691                                     0
# 370299                                    0
#
# [517036 rows x 129 columns]

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train,y_train)
y_pred=nb.predict(X_test)

# %%
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.5856499449428669

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
recall = confusion_matrix.iloc[1][1]/ (confusion_matrix.iloc[1][1]+ confusion_matrix.iloc[1][0])
recall*100
# Out:
# 85.65362228648826

# %%
confusion_matrix
# Out:
# Predicted      No    Yes
# Actual
# No         106375  87896
# Yes          3919  23398

# %%
y_test
# Out:
# 207968    Yes
# 375080     No
# 468637     No
# 144077    Yes
# 385306    Yes
#          ...
# 39452      No
# 170910     No
# 627131     No
# 425650     No
# 557053     No
# Name: Incident occured, Length: 221588, dtype: category
# Categories (2, object): ['No', 'Yes']

# %%
data[data['Incident occured'] == 'Yes']
# Out:
#         Incident Day of Week_Friday  Incident Day of Week_Monday  \
# 310998                            0                            1
# 332693                            0                            0
# 320470                            0                            0
# 337814                            0                            0
# 393181                            0                            0
# ...                             ...                          ...
# 285493                            0                            0
# 235011                            0                            0
# 326124                            0                            0
# 360099                            0                            0
# 311004                            0                            0
#
#         Incident Day of Week_Saturday  Incident Day of Week_Sunday  \
# 310998                              0                            0
# 332693                              1                            0
# 320470                              0                            0
# 337814                              0                            0
# 393181                              1                            0
# ...                               ...                          ...
# 285493                              0                            0
# 235011                              0                            0
# 326124                              0                            0
# 360099                              0                            0
# 311004                              0                            1
#
#         Incident Day of Week_Thursday  Incident Day of Week_Tuesday  \
# 310998                              0                             0
# 332693                              0                             0
# 320470                              0                             1
# 337814                              1                             0
# 393181                              0                             0
# ...                               ...                           ...
# 285493                              0                             0
# 235011                              0                             0
# 326124                              0                             0
# 360099                              0                             1
# 311004                              0                             0
#
#         Incident Day of Week_Wednesday  hour_range_0-3  hour_range_12-15  \
# 310998                               0               1                 0
# 332693                               0               1                 0
# 320470                               0               0                 0
# 337814                               0               0                 0
# 393181                               0               0                 0
# ...                                ...             ...               ...
# 285493                               1               1                 0
# 235011                               1               0                 1
# 326124                               1               0                 0
# 360099                               0               0                 0
# 311004                               0               0                 0
#
#         hour_range_16-19  ...  Analysis Neighborhood_Treasure Island  \
# 310998                 0  ...                                      0
# 332693                 0  ...                                      0
# 320470                 0  ...                                      0
# 337814                 0  ...                                      0
# 393181                 0  ...                                      0
# ...                  ...  ...                                    ...
